# %% [markdown]
# # Import Libs & Data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from scipy import stats
from scipy.stats import norm, skew

from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.base import clone

# XGBoost
import xgboost as xgb

# warning 
import warnings
warnings.filterwarnings('ignore')

# %%
column_name = ["MPG", "Cylinders", "Displacement","Horsepower","Weight","Acceleration","Model Year", "Origin"]
data = pd.read_csv("auto-mpg.data", names = column_name, na_values = "?", comment = "\t",sep = " ", skipinitialspace = True)

# %%
data = data.rename(columns = {"MPG":"target"})
data.head()
# Out:
#    target  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
data.shape
# Out:
# (398, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   target        398 non-null    float64
#  1   Cylinders     398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   Horsepower    392 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Acceleration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB

# %%
data.describe()
# Out:
#            target   Cylinders  Displacement  Horsepower       Weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# # Missing Values

# %%
data.isna().sum()
# Out:
# target          0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
data['Horsepower'] = data['Horsepower'].fillna(data['Horsepower'].mean())

# %%
plt.figure(figsize = (14,10))
sns.distplot(data['Horsepower'], color = 'orange')

# %% [markdown]
# # EDA

# %%
corr_matrix = data.corr()
sns.clustermap(corr_matrix, annot = True, fmt = ".2f")

# %%
sns.pairplot(data, diag_kind = "kde", markers = "+")

# %% [markdown]
# "cylinders" and "origin" can be categorical

# %%
def count_plot(a):
    plt.figure(figsize = (10,8))
    sns.countplot(a)
    plt.show()
    print(a.value_counts())

# %%
count_plot(data['Cylinders'])
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: Cylinders, dtype: int64

# %%
count_plot(data["Origin"])
# Out:
# 1    249
# 3     79
# 2     70
# Name: Origin, dtype: int64

# %% [markdown]
# ## Outlier Detection

# %%
for c in data.columns:
    sns.boxplot(x = c, data = data, orient = "v")
    plt.title(c)
    plt.show()

# %% [markdown]
# "horsepowder" and "acceleration" have got outliers.

# %%
def outlier_detect(a):
    thr = 1.5
    a_desc = a.describe()
    q3_hp = a_desc[6]
    q1_hp = a_desc[4]
    IQR_hp = q3_hp - q1_hp
    top_limit_hp = q3_hp + thr * IQR_hp
    bottom_limit_hp = q1_hp - thr * IQR_hp
    
    filter_hp_top = a < top_limit_hp
    filter_hp_bottom = bottom_limit_hp < a
    filter_hp = filter_hp_top & filter_hp_bottom
    return filter_hp  # Don't forget data = data[filter_hp]  use after this function !

# %%
filter_hp = outlier_detect(data["Horsepower"])
data = data[filter_hp]

# %%
filter_hp = outlier_detect(data["Acceleration"])
data = data[filter_hp]

# %%
data.shape
# Out:
# (381, 8)

# %% [markdown]
#  # Feature Engineering

# %% [markdown]
# ## Skewness

# %%
plt.figure(figsize = (12,8))
sns.distplot(data['target'], fit = norm) # black line gaussian dist.

# %%
(mu, sigma) = norm.fit(data['target'])
print("mu : {} | sigma : {}".format(mu,sigma))
# Out:
# mu : 23.76167979002625 | sigma : 7.58107889968785

# %%
# qqplot
plt.figure(figsize = (12,8))
stats.probplot(data['target'], plot = plt)
plt.show()

# %%
# log transform
data['target'] = np.log1p(data['target'])

plt.figure(figsize = (12,8))
sns.distplot(data['target'], fit = norm)
plt.show()

# %%
(mu, sigma) = norm.fit(data['target'])
print("mu : {} | sigma : {}".format(mu,sigma))
# Out:
# mu : 3.161688999706393 | sigma : 0.31140968687258697

# %%
# after log transform qqplot
plt.figure(figsize = (12,8))
stats.probplot(data['target'], plot = plt)
plt.show()

# %%
# feature -independent variable
skewed_feats = data.apply(lambda x: skew(x.dropna())).sort_values(ascending = False)
skewness = pd.DataFrame(skewed_feats, columns = ["skewed"])
print(skewness) #everyone betwwen -1 and 1  
                # Note : Box - Cox Transformation
# Out:
#                 skewed
# Origin        0.882740
# Horsepower    0.855351
# Displacement  0.702323
# Cylinders     0.598230
# Weight        0.566934
# Acceleration  0.256853
# Model Year   -0.010564
# target       -0.113193

# %% [markdown]
# ## One Hot Encoding

# %%
data["Cylinders"] = data["Cylinders"].astype(str)
data["Origin"] = data["Origin"].astype(str)

data = pd.get_dummies(data)

# %% [markdown]
# # Train - Test Split

# %% [markdown]
# ## Split

# %%
X = data.drop(['target'], axis = 1)
y = data['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ## Scale

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %% [markdown]
# # Model

# %% [markdown]
# ## LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_predict = lr.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ",mse)
# Out:
# mse :  0.01217238018642712

# %% [markdown]
# ## Ridge or TikhonovRegression (L2)

# %%
ridge = Ridge(random_state=42, max_iter=10000)
alphas = np.logspace(-4,-0.5,30)
tuned_params = [{'alpha' : alphas}]

clf = GridSearchCV(ridge, tuned_params, cv = 5, scoring='neg_mean_squared_error', refit = True)
clf.fit(X_train, y_train)

scores = clf.cv_results_['mean_test_score']
scores_std = clf.cv_results_["std_test_score"]

ridge = clf.best_estimator_
print("Ridge Best Estimators : ",ridge)

y_predict = clf.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ",mse)
# Out:
# Ridge Best Estimators :  Ridge(alpha=0.31622776601683794, max_iter=10000, random_state=42)
# mse :  0.012128419691363811

# %%
plt.figure(figsize = (12,8))
plt.semilogx(alphas, scores)
plt.xlabel("alpha")
plt.ylabel("score")
plt.title("Ridge")
# Out:
# Text(0.5, 1.0, 'Ridge')

# %% [markdown]
# ## Lasso Regression (L1)

# %%
lasso = Lasso(random_state=42, max_iter=10000)
alphas = np.logspace(-4, -0.5, 30)

tuned_parameters = [{'alpha': alphas}]

clf = GridSearchCV(lasso, tuned_parameters, cv = 5, scoring = 'neg_mean_squared_error', refit=True)
clf.fit(X_train, y_train)
scores = clf.cv_results_['mean_test_score']
scores_std = clf.cv_results_['std_test_score']

lasso = clf.best_estimator_
print("Lasso Best Estimator: ", lasso)

y_predict = clf.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ", mse)
# Out:
# Lasso Best Estimator:  Lasso(alpha=0.008531678524172814, max_iter=10000, random_state=42)
# mse :  0.011231559232940705

# %%
plt.figure()
plt.semilogx(alphas, scores)
plt.xlabel("alpha")
plt.ylabel("score")
plt.title("Lasso")
# Out:
# Text(0.5, 1.0, 'Lasso')

# %% [markdown]
# ## ElasticNet

# %%
parametersGrid = {"alpha": alphas,
                  "l1_ratio": np.arange(0.0, 1.0, 0.05)}

eNet = ElasticNet(random_state=42, max_iter=10000)
clf = GridSearchCV(eNet, parametersGrid, cv=5, scoring='neg_mean_squared_error', refit=True)
clf.fit(X_train, y_train)

eNet = clf.best_estimator_
print("ElasticNet Best Estimator : ", eNet)

y_predict = clf.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ", mse)
# Out:
# ElasticNet Best Estimator :  ElasticNet(alpha=0.011264816923358867, l1_ratio=0.8, max_iter=10000,
#            random_state=42)
# mse :  0.01123742530074753

# %% [markdown]
# # XGBoost

# %%
parametersGrid = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], 
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500,1000]}

model_xgb = xgb.XGBRegressor()

clf = GridSearchCV(model_xgb, parametersGrid, cv = 5, scoring='neg_mean_squared_error', refit=True, n_jobs = 5, verbose=True)

clf.fit(X_train, y_train)
model_xgb = clf.best_estimator_

print("XGBoost Best Parameters : ", model_xgb)
y_predict = clf.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ",mse)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=5)]: Done  90 out of  90 | elapsed:   26.6s finished
# [23:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# [23:55:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ...

# %% [markdown]
# # Averaging Model

# %%
class AveragingModels():
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([model.predict(X) for model in self.models_])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (model_xgb, lasso))
averaged_models.fit(X_train, y_train)

y_predict = averaged_models.predict(X_test)
mse = mean_squared_error(y_test, y_predict)
print("mse : ", mse)
# Out:
# [23:58:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# [23:58:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [23:58:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.2.0/src/objective/regression_obj.cu:174: reg:linear is now deprecated in favor of reg:squarederror.
# mse :  0.009431841950359779

# %% [markdown]
# # Final

# %% [markdown]
# - Linear Regression MSE : 0.01217238018642712
# - Ridge (L2) MSE : 0.012128419691363811
# - Lasso (L1) MSE : 0.011231559232940705
# - ElasticNet MSE : 0.01123742530074753
# - XGBoost MSE : 0.010509000451871406
# - Averaging Model MSE : 0.009431841950359779
